# %% [markdown]
# # Assignment 3
#
# ## Predict whether a mammogram mass is benign or malignant
#
# We'll be using the "mammographic masses" public dataset from the UCI repository (source: https://archive.ics.uci.edu/ml/datasets/Mammographic+Mass)
#
# This data contains 961 instances of masses detected in mammograms, and contains the following attributes:
#
#
#    1. BI-RADS assessment: 1 to 5 (ordinal)
#    2. Age: patient's age in years (integer)
#    3. Shape: mass shape: round=1 oval=2 lobular=3 irregular=4 (nominal)
#    4. Margin: mass margin: circumscribed=1 microlobulated=2 obscured=3 ill-defined=4 spiculated=5 (nominal)
#    5. Density: mass density high=1 iso=2 low=3 fat-containing=4 (ordinal)
#    6. Severity: benign=0 or malignant=1 (binominal)
#
# BI-RADS is an assesment of how confident the severity classification is; it is not a "predictive" attribute and so we will discard it. The age, shape, margin, and density attributes are the features that we will build our model with, and "severity" is the classification we will attempt to predict based on those attributes.
#
# Although "shape" and "margin" are nominal data types, which sklearn typically doesn't deal with well, they are close enough to ordinal that we shouldn't just discard them. The "shape" for example is ordered increasingly from round to irregular.
#
# A lot of unnecessary anguish and surgery arises from false positives arising from mammogram results. If we can build a better way to interpret them through supervised machine learning, it could improve a lot of lives.
#
# ## Your assignment
#
# Build a Multi-Layer Perceptron and train it to classify masses as benign or malignant based on its features.
#
# The data needs to be cleaned; many rows contain missing data, and there may be erroneous data identifiable as outliers as well.
#
# Remember to normalize your data first! And experiment with different topologies, optimizers, and hyperparameters.
#
# I was able to achieve over 80% accuracy - can you beat that?

# %% [markdown]
# ## Let's begin: prepare your data
#
# Start by importing the mammographic_masses.data.txt file into a Pandas dataframe (hint: use read_csv) and take a look at it.

# %%
import numpy as np 
import pandas as pd 

mm = pd.read_csv("mammographic_masses.data")
mm
# Out:
#      5  67  3 5.1 3.1  1
# 0    4  43  1   1   ?  1
# 1    5  58  4   5   3  1
# 2    4  28  1   1   3  0
# 3    5  74  1   5   ?  1
# 4    4  65  1   ?   3  0
# ..  ..  .. ..  ..  .. ..
# 955  4  47  2   1   3  0
# 956  4  56  4   5   3  1
# 957  4  64  4   5   3  0
# 958  5  66  4   5   3  1
# 959  4  62  3   3   3  0
#
# [960 rows x 6 columns]

# %% [markdown]
# Make sure you use the optional parmaters in read_csv to convert missing data (indicated by a ?) into NaN, and to add the appropriate column names (BI_RADS, age, shape, margin, density, and severity):

# %%
columns = ['BI-RADS assessment', 'Age', 'Shape', 'Margin', 'Density', 'Severity']
mm_dataset = pd.read_csv('mammographic_masses.data', names = columns, na_values=['?'])

# %% [markdown]
# Evaluate whether the data needs cleaning; your model is only as good as the data it's given. Hint: use describe() on the dataframe.

# %%
mm_dataset.describe()
# Out:
#        BI-RADS assessment         Age       Shape      Margin     Density  \
# count          959.000000  956.000000  930.000000  913.000000  885.000000
# mean             4.348279   55.487448    2.721505    2.796276    2.910734
# std              1.783031   14.480131    1.242792    1.566546    0.380444
# min              0.000000   18.000000    1.000000    1.000000    1.000000
# 25%              4.000000   45.000000    2.000000    1.000000    3.000000
# 50%              4.000000   57.000000    3.000000    3.000000    3.000000
# 75%              5.000000   66.000000    4.000000    4.000000    3.000000
# max             55.000000   96.000000    4.000000    5.000000    4.000000
#
#          Severity
# count  961.000000
# mean     0.463059
# std      0.498893
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000

# %% [markdown]
# There are quite a few missing values in the data set. Before we just drop every row that's missing data, let's make sure we don't bias our data in doing so. Does there appear to be any sort of correlation to what sort of data has missing fields? If there were, we'd have to try and go back and fill that data in.

# %%
mm_dataset.loc[(mm_dataset['Age'].isnull())   |
               (mm_dataset['Shape'].isnull()) |
               (mm_dataset['Margin'].isnull()) |
               (mm_dataset['Density'].isnull())]
# Out:
#      BI-RADS assessment   Age  Shape  Margin  Density  Severity
# 1                   4.0  43.0    1.0     1.0      NaN         1
# 4                   5.0  74.0    1.0     5.0      NaN         1
# 5                   4.0  65.0    1.0     NaN      3.0         0
# 6                   4.0  70.0    NaN     NaN      3.0         0
# 7                   5.0  42.0    1.0     NaN      3.0         0
# ..                  ...   ...    ...     ...      ...       ...
# 778                 4.0  60.0    NaN     4.0      3.0         0
# 819                 4.0  35.0    3.0     NaN      2.0         0
# 824                 6.0  40.0    NaN     3.0      4.0         1
# 884                 5.0   NaN    4.0     4.0      3.0         1
# 923                 5.0   NaN    4.0     3.0      3.0         1
#
# [130 rows x 6 columns]

# %% [markdown]
# If the missing data seems randomly distributed, go ahead and drop rows with missing data. Hint: use dropna().

# %%
mm_dataset = mm_dataset.dropna()
mm_dataset
# Out:
#      BI-RADS assessment   Age  Shape  Margin  Density  Severity
# 0                   5.0  67.0    3.0     5.0      3.0         1
# 2                   5.0  58.0    4.0     5.0      3.0         1
# 3                   4.0  28.0    1.0     1.0      3.0         0
# 8                   5.0  57.0    1.0     5.0      3.0         1
# 10                  5.0  76.0    1.0     4.0      3.0         1
# ..                  ...   ...    ...     ...      ...       ...
# 956                 4.0  47.0    2.0     1.0      3.0         0
# 957                 4.0  56.0    4.0     5.0      3.0         1
# 958                 4.0  64.0    4.0     5.0      3.0         0
# 959                 5.0  66.0    4.0     5.0      3.0         1
# 960                 4.0  62.0    3.0     3.0      3.0         0
#
# [830 rows x 6 columns]

# %%
mm_dataset.describe()
# Out:
#        BI-RADS assessment         Age       Shape      Margin     Density  \
# count          830.000000  830.000000  830.000000  830.000000  830.000000
# mean             4.393976   55.781928    2.781928    2.813253    2.915663
# std              1.888371   14.671782    1.242361    1.567175    0.350936
# min              0.000000   18.000000    1.000000    1.000000    1.000000
# 25%              4.000000   46.000000    2.000000    1.000000    3.000000
# 50%              4.000000   57.000000    3.000000    3.000000    3.000000
# 75%              5.000000   66.000000    4.000000    4.000000    3.000000
# max             55.000000   96.000000    4.000000    5.000000    4.000000
#
#          Severity
# count  830.000000
# mean     0.485542
# std      0.500092
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000

# %% [markdown]
# Next you'll need to convert the Pandas dataframes into numpy arrays that can be used by scikit_learn. Create an array that extracts only the feature data we want to work with (age, shape, margin, and density) and another array that contains the classes (severity). You'll also need an array of the feature name labels.

# %%
features = mm_dataset[['Age', 'Shape', 'Margin', 'Density']].values
classes = mm_dataset['Severity'].values
feature_name = ['Age', 'Shape', 'Margin', 'Density']
features
# Out:
# array([[67.,  3.,  5.,  3.],
#        [58.,  4.,  5.,  3.],
#        [28.,  1.,  1.,  3.],
#        ...,
#        [64.,  4.,  5.,  3.],
#        [66.,  4.,  5.,  3.],
#        [62.,  3.,  3.,  3.]])

# %% [markdown]
# Some of our models require the input data to be normalized, so go ahead and normalize the attribute data. Hint: use preprocessing.StandardScaler().

# %%
from numpy import asarray
from sklearn import preprocessing

scaler = preprocessing.StandardScaler()
features_scaled = scaler.fit_transform(features)
features_scaled
# Out:
# array([[ 0.7650629 ,  0.17563638,  1.39618483,  0.24046607],
#        [ 0.15127063,  0.98104077,  1.39618483,  0.24046607],
#        [-1.89470363, -1.43517241, -1.157718  ,  0.24046607],
#        ...,
#        [ 0.56046548,  0.98104077,  1.39618483,  0.24046607],
#        [ 0.69686376,  0.98104077,  1.39618483,  0.24046607],
#        [ 0.42406719,  0.17563638,  0.11923341,  0.24046607]])

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(mm_dataset, classes, test_size=0.4)

# %% [markdown]
# ## Now build your neural network.
#
# Now set up an actual MLP model using Keras:

# %%
import keras
from keras.layers import Dense, Dropout, Activation
from keras.models import Sequential

#np.random.seed(42)

#def create_model():
model = Sequential()
model.add(Dense(4, input_dim=6,  activation='relu'))#kernel_initializer='normal',
model.add(Dropout(0.2))
model.add(Dense(1, kernel_initializer='normal', activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    
model.summary()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_80 (Dense)            (None, 4)                 28
#
#  dropout_25 (Dropout)        (None, 4)                 0
#
#  dense_81 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 33
# Trainable params: 33
# Non-trainable params: 0
# _________________________________________________________________

# %%
#from sklearn.model_selection import cross_val_score
#from keras.wrappers.scikit_learn import KerasClassifier
#estimate = KerasClassifier(build_fn=create_model, nb_epoch = 100, verbose=0)
#cv_scores = cross_val_score(estimate, features_scaled, classes, cv=10)
#cv_scores.mean()
#from sklearn.model_selection import train_test_splitm

x_train, x_test, y_train, y_test = train_test_split(mm_dataset, classes, test_size= 0.4, )#ramdom_state=0)

x_train = np.asarray(x_train).astype(np.float32)
y_train = np.asarray(y_train).astype(np.float32)
model.compile(loss='binary_crossentropy', optimizer='RMSprop', metrics=['accuracy'])

trained = model.fit(x_train, y_train, batch_size=16, epochs = 100, validation_data=(x_test, y_test), verbose=2,) #/*callbacks=[tf.docs.modeling.EpochDots()] */)
# Out:
# Epoch 1/100
# 32/32 - 5s - loss: 0.6967 - accuracy: 0.4659 - val_loss: 0.6748 - val_accuracy: 0.5422 - 5s/epoch - 161ms/step
# Epoch 2/100
# 32/32 - 0s - loss: 0.6914 - accuracy: 0.4317 - val_loss: 0.6815 - val_accuracy: 0.5512 - 360ms/epoch - 11ms/step
# Epoch 3/100
# 32/32 - 0s - loss: 0.6880 - accuracy: 0.4900 - val_loss: 0.6762 - val_accuracy: 0.5422 - 391ms/epoch - 12ms/step
# Epoch 4/100
# 32/32 - 0s - loss: 0.6849 - accuracy: 0.4980 - val_loss: 0.6698 - val_accuracy: 0.5422 - 415ms/epoch - 13ms/step
# Epoch 5/100
# 32/32 - 0s - loss: 0.6849 - accuracy: 0.4819 - val_loss: 0.6705 - val_accuracy: 0.5572 - 363ms/epoch - 11ms/step
# Epoch 6/100
# 32/32 - 0s - loss: 0.6824 - accuracy: 0.4920 - val_loss: 0.6682 - val_accuracy: 0.5663 - 345ms/epoch - 11ms/step
# Epoch 7/100
# 32/32 - 0s - loss: 0.6807 - accuracy: 0.4839 - val_loss: 0.6720 - val_accuracy: 0.6566 - 352ms/epoch - 11ms/step
# Epoch 8/100
# 32/32 - 0s - loss: 0.6824 - accuracy: 0.5763 - val_loss: 0.6688 - val_accuracy: 0.6386 - 347ms/epoch - 11ms/step
# Epoch 9/100
# 32/32 - 0s - loss: 0.6805 - accuracy: 0.5201 - val_loss: 0.6683 - val_accuracy: 0.6928 - 298ms/epoch - 9ms/step
# Epoch 10/100
# 32/32 - 0s - loss: 0.6708 - accuracy: 0.5643 - val_loss: 0.6633 - val_accuracy: 0.6687 - 290ms/epoch - 9ms/step
# Epoch 11/100
# 32/32 - 0s - loss: 0.6742 - accuracy: 0.5462 - val_loss: 0.6599 - val_accuracy: 0.6657 - 320ms/epoch - 10ms/step
# Epoch 12/100
# 32/32 - 0s - loss: 0.6690 - accuracy: 0.5341 - val_loss: 0.6623 - val_accuracy: 0.7711 - 267ms/epoch - 8ms/step
# Epoch 13/100
# 32/32 - 0s - loss: 0.6739 - accuracy: 0.6084 - val_loss: 0.6539 - val_accuracy: 0.7018 - 251ms/epoch - 8ms/step
# Epoch 14/100
# 32/32 - 0s - loss: 0.6659 - accuracy: 0.5562 - val_loss: 0.6525 - val_accuracy: 0.7410 - 252ms/epoch - 8ms/step
# Epoch 15/100
# 32/32 - 0s - loss: 0.6699 - accuracy: 0.5743 - val_loss: 0.6503 - val_accuracy: 0.7711 - 256ms/epoch - 8ms/step
# Epoch 16/100
# 32/32 - 0s - loss: 0.6630 - accuracy: 0.6024 - val_loss: 0.6519 - val_accuracy: 0.8283 - 234ms/epoch - 7ms/step
# Epoch 17/100
# 32/32 - 0s - loss: 0.6576 - accuracy: 0.6667 - val_loss: 0.6403 - val_accuracy: 0.7892 - 227ms/epoch - 7ms/step
# Epoch 18/100
# 32/32 - 0s - loss: 0.6515 - accuracy: 0.6365 - val_loss: 0.6298 - val_accuracy: 0.7319 - 231ms/epoch - 7ms/step
# Epoch 19/100
# 32/32 - 0s - loss: 0.6584 - accuracy: 0.5863 - val_loss: 0.6323 - val_accuracy: 0.8253 - 230ms/epoch - 7ms/step
# Epoch 20/100
# 32/32 - 0s - loss: 0.6412 - accuracy: 0.6928 - val_loss: 0.6256 - val_accuracy: 0.8343 - 232ms/epoch - 7ms/step
# Epoch 21/100
# 32/32 - 0s - loss: 0.6321 - accuracy: 0.7149 - val_loss: 0.6175 - val_accuracy: 0.8283 - 225ms/epoch - 7ms/step
# Epoch 22/100
# 32/32 - 0s - loss: 0.6368 - accuracy: 0.7068 - val_loss: 0.6101 - val_accuracy: 0.8223 - 206ms/epoch - 6ms/step
# Epoch 23/100
# 32/32 - 0s - loss: 0.6286 - accuracy: 0.7149 - val_loss: 0.6029 - val_accuracy: 0.8193 - 212ms/epoch - 7ms/step
# Epoch 24/100
# 32/32 - 0s - loss: 0.6201 - accuracy: 0.7269 - val_loss: 0.5927 - val_accuracy: 0.8253 - 208ms/epoch - 6ms/step
# Epoch 25/100
# 32/32 - 0s - loss: 0.6064 - accuracy: 0.7329 - val_loss: 0.5788 - val_accuracy: 0.8223 - 203ms/epoch - 6ms/step
# Epoch 26/100
# 32/32 - 0s - loss: 0.5853 - accuracy: 0.7671 - val_loss: 0.5679 - val_accuracy: 0.8253 - 212ms/epoch - 7ms/step
# Epoch 27/100
# 32/32 - 0s - loss: 0.5807 - accuracy: 0.7450 - val_loss: 0.5520 - val_accuracy: 0.8223 - 220ms/epoch - 7ms/step
# Epoch 28/100
# 32/32 - 0s - loss: 0.5649 - accuracy: 0.7631 - val_loss: 0.5420 - val_accuracy: 0.8223 - 212ms/epoch - 7ms/step
# Epoch 29/100
# 32/32 - 0s - loss: 0.5732 - accuracy: 0.7390 - val_loss: 0.5355 - val_accuracy: 0.8253 - 204ms/epoch - 6ms/step
# Epoch 30/100
# 32/32 - 0s - loss: 0.5654 - accuracy: 0.7450 - val_loss: 0.5245 - val_accuracy: 0.8223 - 214ms/epoch - 7ms/step
# Epoch 31/100
# 32/32 - 0s - loss: 0.5509 - accuracy: 0.7590 - val_loss: 0.5209 - val_accuracy: 0.8283 - 214ms/epoch - 7ms/step
# Epoch 32/100
# 32/32 - 0s - loss: 0.5511 - accuracy: 0.7510 - val_loss: 0.5123 - val_accuracy: 0.8253 - 213ms/epoch - 7ms/step
# Epoch 33/100
# 32/32 - 0s - loss: 0.5527 - accuracy: 0.7390 - val_loss: 0.5083 - val_accuracy: 0.8283 - 217ms/epoch - 7ms/step
# Epoch 34/100
# 32/32 - 0s - loss: 0.5443 - accuracy: 0.7510 - val_loss: 0.5055 - val_accuracy: 0.8373 - 207ms/epoch - 6ms/step
# Epoch 35/100
# 32/32 - 0s - loss: 0.5508 - accuracy: 0.7329 - val_loss: 0.4998 - val_accuracy: 0.8373 - 210ms/epoch - 7ms/step
# Epoch 36/100
# 32/32 - 0s - loss: 0.5403 - accuracy: 0.7490 - val_loss: 0.4891 - val_accuracy: 0.8283 - 204ms/epoch - 6ms/step
# Epoch 37/100
# 32/32 - 0s - loss: 0.5249 - accuracy: 0.7610 - val_loss: 0.4907 - val_accuracy: 0.8373 - 216ms/epoch - 7ms/step
# Epoch 38/100
# 32/32 - 0s - loss: 0.5426 - accuracy: 0.7410 - val_loss: 0.4828 - val_accuracy: 0.8373 - 217ms/epoch - 7ms/step
# Epoch 39/100
# 32/32 - 0s - loss: 0.5256 - accuracy: 0.7570 - val_loss: 0.4753 - val_accuracy: 0.8373 - 208ms/epoch - 7ms/step
# Epoch 40/100
# 32/32 - 0s - loss: 0.5156 - accuracy: 0.7590 - val_loss: 0.4720 - val_accuracy: 0.8373 - 250ms/epoch - 8ms/step
# Epoch 41/100
# 32/32 - 0s - loss: 0.5044 - accuracy: 0.7751 - val_loss: 0.4589 - val_accuracy: 0.8343 - 202ms/epoch - 6ms/step
# Epoch 42/100
# 32/32 - 0s - loss: 0.5264 - accuracy: 0.7450 - val_loss: 0.4552 - val_accuracy: 0.8373 - 188ms/epoch - 6ms/step
# Epoch 43/100
# 32/32 - 0s - loss: 0.5120 - accuracy: 0.7590 - val_loss: 0.4508 - val_accuracy: 0.8373 - 192ms/epoch - 6ms/step
# Epoch 44/100
# 32/32 - 0s - loss: 0.4953 - accuracy: 0.7711 - val_loss: 0.4490 - val_accuracy: 0.8404 - 183ms/epoch - 6ms/step
# Epoch 45/100
# 32/32 - 0s - loss: 0.5061 - accuracy: 0.7590 - val_loss: 0.4485 - val_accuracy: 0.8494 - 193ms/epoch - 6ms/step
# Epoch 46/100
# 32/32 - 0s - loss: 0.4948 - accuracy: 0.7691 - val_loss: 0.4397 - val_accuracy: 0.8494 - 187ms/epoch - 6ms/step
# Epoch 47/100
# 32/32 - 0s - loss: 0.5063 - accuracy: 0.7590 - val_loss: 0.4563 - val_accuracy: 0.8675 - 181ms/epoch - 6ms/step
# Epoch 48/100
# 32/32 - 0s - loss: 0.4852 - accuracy: 0.7932 - val_loss: 0.4309 - val_accuracy: 0.8494 - 187ms/epoch - 6ms/step
# Epoch 49/100
# 32/32 - 0s - loss: 0.4803 - accuracy: 0.7831 - val_loss: 0.4265 - val_accuracy: 0.8494 - 182ms/epoch - 6ms/step
# Epoch 50/100
# 32/32 - 0s - loss: 0.4805 - accuracy: 0.7771 - val_loss: 0.4261 - val_accuracy: 0.8645 - 183ms/epoch - 6ms/step
# Epoch 51/100
# 32/32 - 0s - loss: 0.4948 - accuracy: 0.7671 - val_loss: 0.4292 - val_accuracy: 0.8705 - 185ms/epoch - 6ms/step
# Epoch 52/100
# 32/32 - 0s - loss: 0.4618 - accuracy: 0.7932 - val_loss: 0.4175 - val_accuracy: 0.8675 - 182ms/epoch - 6ms/step
# Epoch 53/100
# 32/32 - 0s - loss: 0.5074 - accuracy: 0.7510 - val_loss: 0.4134 - val_accuracy: 0.8675 - 184ms/epoch - 6ms/step
# Epoch 54/100
# 32/32 - 0s - loss: 0.4897 - accuracy: 0.7671 - val_loss: 0.4139 - val_accuracy: 0.8705 - 187ms/epoch - 6ms/step
# Epoch 55/100
# 32/32 - 0s - loss: 0.4668 - accuracy: 0.8012 - val_loss: 0.3999 - val_accuracy: 0.8675 - 183ms/epoch - 6ms/step
# Epoch 56/100
# 32/32 - 0s - loss: 0.4524 - accuracy: 0.7972 - val_loss: 0.3922 - val_accuracy: 0.8675 - 189ms/epoch - 6ms/step
# Epoch 57/100
# 32/32 - 0s - loss: 0.4565 - accuracy: 0.7972 - val_loss: 0.4053 - val_accuracy: 0.8855 - 187ms/epoch - 6ms/step
# Epoch 58/100
# 32/32 - 0s - loss: 0.4872 - accuracy: 0.7851 - val_loss: 0.3845 - val_accuracy: 0.8705 - 183ms/epoch - 6ms/step
# Epoch 59/100
# 32/32 - 0s - loss: 0.4710 - accuracy: 0.7892 - val_loss: 0.3839 - val_accuracy: 0.8765 - 184ms/epoch - 6ms/step
# Epoch 60/100
# 32/32 - 0s - loss: 0.4620 - accuracy: 0.7972 - val_loss: 0.3848 - val_accuracy: 0.8795 - 215ms/epoch - 7ms/step
# Epoch 61/100
# 32/32 - 0s - loss: 0.4391 - accuracy: 0.8153 - val_loss: 0.3821 - val_accuracy: 0.9096 - 220ms/epoch - 7ms/step
# Epoch 62/100
# 32/32 - 0s - loss: 0.4457 - accuracy: 0.8052 - val_loss: 0.3766 - val_accuracy: 0.9127 - 195ms/epoch - 6ms/step
# Epoch 63/100
# 32/32 - 0s - loss: 0.4212 - accuracy: 0.8233 - val_loss: 0.3656 - val_accuracy: 0.8946 - 183ms/epoch - 6ms/step
# Epoch 64/100
# 32/32 - 0s - loss: 0.4211 - accuracy: 0.8213 - val_loss: 0.3489 - val_accuracy: 0.8795 - 200ms/epoch - 6ms/step
# Epoch 65/100
# 32/32 - 0s - loss: 0.4418 - accuracy: 0.8072 - val_loss: 0.3487 - val_accuracy: 0.8825 - 202ms/epoch - 6ms/step
# Epoch 66/100
# 32/32 - 0s - loss: 0.4381 - accuracy: 0.8092 - val_loss: 0.3404 - val_accuracy: 0.8825 - 206ms/epoch - 6ms/step
# Epoch 67/100
# 32/32 - 0s - loss: 0.4339 - accuracy: 0.8092 - val_loss: 0.3649 - val_accuracy: 0.9277 - 200ms/epoch - 6ms/step
# Epoch 68/100
# 32/32 - 0s - loss: 0.4350 - accuracy: 0.8092 - val_loss: 0.3459 - val_accuracy: 0.9187 - 188ms/epoch - 6ms/step
# Epoch 69/100
# 32/32 - 0s - loss: 0.4218 - accuracy: 0.8273 - val_loss: 0.3274 - val_accuracy: 0.9157 - 181ms/epoch - 6ms/step
# Epoch 70/100
# 32/32 - 0s - loss: 0.4265 - accuracy: 0.8112 - val_loss: 0.3379 - val_accuracy: 0.9277 - 181ms/epoch - 6ms/step
# Epoch 71/100
# 32/32 - 0s - loss: 0.4275 - accuracy: 0.8233 - val_loss: 0.3184 - val_accuracy: 0.9127 - 185ms/epoch - 6ms/step
# Epoch 72/100
# 32/32 - 0s - loss: 0.4007 - accuracy: 0.8394 - val_loss: 0.3166 - val_accuracy: 0.9277 - 185ms/epoch - 6ms/step
# Epoch 73/100
# 32/32 - 0s - loss: 0.3853 - accuracy: 0.8434 - val_loss: 0.3081 - val_accuracy: 0.9277 - 181ms/epoch - 6ms/step
# Epoch 74/100
# 32/32 - 0s - loss: 0.3822 - accuracy: 0.8514 - val_loss: 0.3067 - val_accuracy: 0.9277 - 183ms/epoch - 6ms/step
# Epoch 75/100
# 32/32 - 0s - loss: 0.3764 - accuracy: 0.8534 - val_loss: 0.2929 - val_accuracy: 0.9337 - 186ms/epoch - 6ms/step
# Epoch 76/100
# 32/32 - 0s - loss: 0.3721 - accuracy: 0.8574 - val_loss: 0.2821 - val_accuracy: 0.9337 - 188ms/epoch - 6ms/step
# Epoch 77/100
# 32/32 - 0s - loss: 0.3828 - accuracy: 0.8474 - val_loss: 0.2866 - val_accuracy: 0.9398 - 186ms/epoch - 6ms/step
# Epoch 78/100
# 32/32 - 0s - loss: 0.3859 - accuracy: 0.8454 - val_loss: 0.2788 - val_accuracy: 0.9428 - 183ms/epoch - 6ms/step
# Epoch 79/100
# 32/32 - 0s - loss: 0.3730 - accuracy: 0.8554 - val_loss: 0.2724 - val_accuracy: 0.9458 - 183ms/epoch - 6ms/step
# Epoch 80/100
# 32/32 - 0s - loss: 0.3609 - accuracy: 0.8614 - val_loss: 0.2740 - val_accuracy: 0.9428 - 185ms/epoch - 6ms/step
# Epoch 81/100
# 32/32 - 0s - loss: 0.3422 - accuracy: 0.8835 - val_loss: 0.2582 - val_accuracy: 0.9488 - 188ms/epoch - 6ms/step
# Epoch 82/100
# 32/32 - 0s - loss: 0.3676 - accuracy: 0.8554 - val_loss: 0.2549 - val_accuracy: 0.9488 - 183ms/epoch - 6ms/step
# Epoch 83/100
# 32/32 - 0s - loss: 0.3375 - accuracy: 0.8735 - val_loss: 0.2567 - val_accuracy: 0.9608 - 186ms/epoch - 6ms/step
# Epoch 84/100
# 32/32 - 0s - loss: 0.3203 - accuracy: 0.8936 - val_loss: 0.2481 - val_accuracy: 0.9578 - 184ms/epoch - 6ms/step
# Epoch 85/100
# 32/32 - 0s - loss: 0.3312 - accuracy: 0.8815 - val_loss: 0.2531 - val_accuracy: 0.9548 - 191ms/epoch - 6ms/step
# Epoch 86/100
# 32/32 - 0s - loss: 0.3290 - accuracy: 0.8855 - val_loss: 0.2318 - val_accuracy: 0.9578 - 185ms/epoch - 6ms/step
# Epoch 87/100
# 32/32 - 0s - loss: 0.3728 - accuracy: 0.8494 - val_loss: 0.2300 - val_accuracy: 0.9608 - 184ms/epoch - 6ms/step
# Epoch 88/100
# 32/32 - 0s - loss: 0.3486 - accuracy: 0.8715 - val_loss: 0.2329 - val_accuracy: 0.9608 - 187ms/epoch - 6ms/step
# Epoch 89/100
# 32/32 - 0s - loss: 0.3267 - accuracy: 0.8795 - val_loss: 0.2154 - val_accuracy: 0.9729 - 179ms/epoch - 6ms/step
# Epoch 90/100
# 32/32 - 0s - loss: 0.3146 - accuracy: 0.8936 - val_loss: 0.2074 - val_accuracy: 0.9789 - 203ms/epoch - 6ms/step
# Epoch 91/100
# 32/32 - 0s - loss: 0.3126 - accuracy: 0.9016 - val_loss: 0.2050 - val_accuracy: 0.9789 - 180ms/epoch - 6ms/step
# Epoch 92/100
# 32/32 - 0s - loss: 0.3169 - accuracy: 0.8936 - val_loss: 0.1976 - val_accuracy: 0.9849 - 182ms/epoch - 6ms/step
# Epoch 93/100
# 32/32 - 0s - loss: 0.3554 - accuracy: 0.8775 - val_loss: 0.1871 - val_accuracy: 0.9849 - 184ms/epoch - 6ms/step
# Epoch 94/100
# 32/32 - 0s - loss: 0.3031 - accuracy: 0.9016 - val_loss: 0.1888 - val_accuracy: 0.9880 - 182ms/epoch - 6ms/step
# Epoch 95/100
# 32/32 - 0s - loss: 0.3353 - accuracy: 0.8815 - val_loss: 0.2013 - val_accuracy: 0.9759 - 182ms/epoch - 6ms/step
# Epoch 96/100
# 32/32 - 0s - loss: 0.2734 - accuracy: 0.9257 - val_loss: 0.2045 - val_accuracy: 0.9729 - 182ms/epoch - 6ms/step
# Epoch 97/100
# 32/32 - 0s - loss: 0.3152 - accuracy: 0.9016 - val_loss: 0.1900 - val_accuracy: 0.9819 - 184ms/epoch - 6ms/step
# Epoch 98/100
# 32/32 - 0s - loss: 0.2637 - accuracy: 0.9297 - val_loss: 0.1664 - val_accuracy: 0.9970 - 182ms/epoch - 6ms/step
# Epoch 99/100
# 32/32 - 0s - loss: 0.2556 - accuracy: 0.9277 - val_loss: 0.1709 - val_accuracy: 0.9880 - 184ms/epoch - 6ms/step
# Epoch 100/100
# 32/32 - 0s - loss: 0.2928 - accuracy: 0.9116 - val_loss: 0.1742 - val_accuracy: 0.9880 - 185ms/epoch - 6ms/step

# %%
score = model.evaluate(x_train, y_train)
print("\n Training Accuracy:", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("\n Testing Accuracy:", score[1])
# Out:
# 16/16 [==============================] - 1s 11ms/step - loss: 0.1835 - accuracy: 0.9960
#
#  Training Accuracy: 0.9959839582443237
#
#  Testing Accuracy: 0.9879518151283264

# %% [markdown]
#  How did you do?
#
# Which topology, and which choice of hyperparameters, performed the best? Feel free to share your results!
